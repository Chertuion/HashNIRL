# %%
import numpy as np

# 你的实验结果
mse_list = [2.0630, 2.2810, 2.1378, 1.7770]
mae_list = [1.1665, 1.1728, 1.1378, 1.0462]

# 计算均值和标准差
mse_mean = np.mean(mse_list)
mse_std = np.std(mse_list)

mae_mean = np.mean(mae_list)
mae_std = np.std(mae_list)

# 输出结果
print(f"MSE: {mse_mean:.4f} ± {mse_std:.4f}")
print(f"MAE: {mae_mean:.4f} ± {mae_std:.4f}")
# Out:
# MSE: 2.0647 ± 0.1836
# MAE: 1.1308 ± 0.0506

# %%
import numpy as np

# 你的实验结果
mse_list = [2.3419, 1.9217, 2.1259, 1.8776]
mae_list = [1.2344, 1.0893, 1.1490, 1.0751]

# 计算均值和标准差
mse_mean = np.mean(mse_list)
mse_std = np.std(mse_list)

mae_mean = np.mean(mae_list)
mae_std = np.std(mae_list)

# 输出结果
print(f"MSE: {mse_mean:.4f} ± {mse_std:.4f}")
print(f"MAE: {mae_mean:.4f} ± {mae_std:.4f}")
# Out:
# MSE: 2.0668 ± 0.1844
# MAE: 1.1369 ± 0.0627

# %%
import numpy as np

mse_list = [3.0911, 3.0154, 3.5681, 2.7875]
mae_list = [1.3092, 1.3556, 1.3882, 1.2744]

mse_mean = np.mean(mse_list)
mse_std = np.std(mse_list)

mae_mean = np.mean(mae_list)
mae_std = np.std(mae_list)

print(f"MSE: {mse_mean:.4f} ± {mse_std:.4f}")
print(f"MAE: {mae_mean:.4f} ± {mae_std:.4f}")
# Out:
# MSE: 3.1155 ± 0.2842
# MAE: 1.3318 ± 0.0435

# %%
import numpy as np

mse_list = [3.0400, 2.5912, 3.6669, 2.2058]
mae_list = [1.3790, 1.2858, 1.5140, 1.1715]

mse_mean = np.mean(mse_list)
mse_std = np.std(mse_list)

mae_mean = np.mean(mae_list)
mae_std = np.std(mae_list)

print(f"MSE: {mse_mean:.4f} ± {mse_std:.4f}")
print(f"MAE: {mae_mean:.4f} ± {mae_std:.4f}")
# Out:
# MSE: 2.8760 ± 0.5438
# MAE: 1.3376 ± 0.1256

# %%
import numpy as np

mse_list = [2.1346, 2.5184, 2.1293, 2.5526]
mae_list = [1.1362, 1.1979, 1.1262, 1.2054]

mse_mean = np.mean(mse_list)
mse_std = np.std(mse_list)

mae_mean = np.mean(mae_list)
mae_std = np.std(mae_list)

print(f"MSE: {mse_mean:.4f} ± {mse_std:.4f}")
print(f"MAE: {mae_mean:.4f} ± {mae_std:.4f}")
# Out:
# MSE: 2.3337 ± 0.2021
# MAE: 1.1664 ± 0.0355

# %%
import numpy as np

mse_list = [3.8475, 2.9763, 6.1185, 3.2746]
mae_list = [1.5253, 1.3481, 1.9850, 1.4214]

mse_mean = np.mean(mse_list)
mse_std = np.std(mse_list)

mae_mean = np.mean(mae_list)
mae_std = np.std(mae_list)

print(f"MSE: {mse_mean:.4f} ± {mse_std:.4f}")
print(f"MAE: {mae_mean:.4f} ± {mae_std:.4f}")
# Out:
# MSE: 4.0542 ± 1.2322
# MAE: 1.5700 ± 0.2478
